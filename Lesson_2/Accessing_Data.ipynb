# %%
import pandas as pd

# %%
df_r = pd.read_csv('winequality-red.csv', sep=';')
df_r.head(5).style.background_gradient(cmap = 'Reds')
# Out:
# <style  type="text/css" >
#     #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col0 {
#             background-color:  #fff5f0;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col1 {
#             background-color:  #d92523;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col2 {
#             background-color:  #fff5f0;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col3 {
#             background-color:  #fff5f0;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col4 {
#             background-color:  #ffeee6;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col5 {
#             background-color:  #fff5f0;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col6 {
#             background-color:  #fff5f0;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col7 {
#             background-color:  #b11218;
#         }    #T_dc563dbe_795c_11ea_8932_b3f8bb81affdrow0_col8 {
#             background-color:  #67000d;
# ...

# %%
df_w = pd.read_csv('winequality-white.csv', sep=';')
df_w.head(5).style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
#     #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col0 {
#             background-color:  #9cd797;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col1 {
#             background-color:  #56b567;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col2 {
#             background-color:  #75c477;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col3 {
#             background-color:  #00441b;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col4 {
#             background-color:  #f7fcf5;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col5 {
#             background-color:  #005723;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col6 {
#             background-color:  #107a37;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col7 {
#             background-color:  #00441b;
#         }    #T_7be7866c_795d_11ea_8932_b3f8bb81affdrow0_col8 {
#             background-color:  #f7fcf5;
# ...

# %%
df_r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null float64
# volatile_acidity        1599 non-null float64
# citric_acid             1599 non-null float64
# residual_sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free_sulfur_dioxide     1599 non-null float64
# total_sulfur-dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed_acidity           4898 non-null float64
# volatile_acidity        4898 non-null float64
# citric_acid             4898 non-null float64
# residual_sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free_sulfur_dioxide     4898 non-null float64
# total_sulfur_dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_r.shape
# Out:
# (1599, 12)

# %%
df_w.shape
# Out:
# (4898, 12)

# %%
sum(df_w.duplicated())
# Out:
# 937

# %%
df_r.nunique()
# Out:
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur-dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df_w.nunique()
# Out:
# fixed_acidity            68
# volatile_acidity        125
# citric_acid              87
# residual_sugar          310
# chlorides               160
# free_sulfur_dioxide     132
# total_sulfur_dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
df_r['density'].mean()
# Out:
# 0.9967466791744833
